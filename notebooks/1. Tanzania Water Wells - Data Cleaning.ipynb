# %% [markdown]
# **Libraries and imports**

# %%
# Main Libraries
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
# Loading dataset for first view
waterwells_Xs = pd.read_csv('../data/X_train.csv')
waterwells_ys = pd.read_csv('../data/y_train.csv')

waterwells = waterwells_Xs.merge(waterwells_ys, how = 'outer', on = 'id')
waterwells.sort_values('id')
# Out:
#           id  amount_tsh date_recorded             funder  gps_height  \
# 9410       0         0.0    2012-11-13              Tasaf           0
# 18428      1         0.0    2011-03-05              Shipo        1978
# 12119      2         0.0    2011-03-27               Lvia           0
# 10629      3        10.0    2013-06-03    Germany Republi        1639
# 2343       4         0.0    2011-03-22               Cmsr           0
# ...      ...         ...           ...                ...         ...
# 15137  74240         0.0    2013-03-22       World Vision        1183
# 8667   74242         0.0    2011-04-12             Danida           0
# 22584  74243         0.0    2012-11-13  Ministry Of Water        1188
# 108    74246        50.0    2011-03-07              Ruthe        1428
# 39131  74247        50.0    2013-02-16            Mission         965
#
#           installer  longitude   latitude               wpt_name  num_private  \
# 9410          TASAF  33.125828  -5.118154                Mratibu            0
# 18428         SHIPO  34.770717  -9.395642                   none            0
# 12119          LVIA  36.115056  -6.279268                Bombani            0
# 10629           CES  37.147432  -3.187555         Area 7 Namba 5            0
# 2343           CMSR  36.164893  -6.099289                Ezeleda            0
# ...             ...        ...        ...                    ...          ...
# 15137  World vision  37.007726  -3.280868  Upendo Primary School            0
# 8667         DANIDA  33.724987  -8.940758            Kwa Mvulula            0
# 22584        Hesawa  33.963539  -1.429477      Kwa Wambura Msege            0
# 108           Ruthe  35.630481  -7.710549                   none            0
# 39131           DWE  35.432998 -10.639270            Kwa Mapunda            0
#
#                          basin  subvillage       region  region_code  \
# 9410           Lake Tanganyika     Majengo       Tabora           14
# 18428                   Rufiji    Magoda C       Iringa           11
# 12119              Wami / Ruvu  Songambele       Dodoma            1
# 10629                  Pangani     Urereni  Kilimanjaro            3
# 2343               Wami / Ruvu     Maata A       Dodoma            1
# ...                        ...         ...          ...          ...
# 15137                  Pangani       Ntuwe       Arusha            2
# 8667                    Rufiji       Itete        Mbeya           12
# 22584            Lake Victoria      Ititwe         Mara           20
# 108                     Rufiji      Kidete       Iringa           11
# 39131  Ruvuma / Southern Coast     Mpakani       Ruvuma           10
#
#        district_code           lga              ward  population  \
# 9410               3          Uyui           Igalula           0
# 18428              4        Njombe            Uwemba          20
# 12119              4      Chamwino           Msamalo           0
# 10629              5           Hai  Masama Magharibi          25
# 2343               4      Chamwino          Majeleko           0
# ...              ...           ...               ...         ...
# 15137              7          Meru          King'ori         350
# 8667               2   Mbeya Rural            Ilungu           0
# 22584              6         Rorya            Komuge          95
# 108                1  Iringa Rural            Kiwere           1
# 39131              2  Songea Rural          Maposeni         900
#
#       public_meeting              recorded_by scheme_management  \
# 9410             NaN  GeoData Consultants Ltd               VWC
# 18428           True  GeoData Consultants Ltd               NaN
# 12119           True  GeoData Consultants Ltd               VWC
# 10629           True  GeoData Consultants Ltd       Water Board
# 2343            True  GeoData Consultants Ltd               VWC
# ...              ...                      ...               ...
# 15137           True  GeoData Consultants Ltd               WUA
# 8667           False  GeoData Consultants Ltd               VWC
# 22584           True  GeoData Consultants Ltd               VWC
# 108             True  GeoData Consultants Ltd               VWC
# 39131           True  GeoData Consultants Ltd               VWC
#
#                      scheme_name permit  construction_year    extraction_type  \
# 9410                         NaN   True                  0            afridev
# 18428                        NaN  False               2008  other - rope pump
# 12119                       Mgun   True                  0               mono
# 10629     Losaa-Kia water supply   True               1999            gravity
# 2343                         NaN   True                  0        nira/tanira
# ...                          ...    ...                ...                ...
# 15137                        NaN  False               2012            gravity
# 8667                         NaN  False                  0            gravity
# 22584       Mradi wa maji Komuge  False               1983        submersible
# 108                       Kiwele   True               2000            gravity
# 39131  Mradi wa maji wa peramiho   True               2009              other
#
#       extraction_type_group extraction_type_class   management  \
# 9410                afridev              handpump          vwc
# 18428             rope pump             rope pump          vwc
# 12119                  mono             motorpump          vwc
# 10629               gravity               gravity  water board
# 2343            nira/tanira              handpump          vwc
# ...                     ...                   ...          ...
# 15137               gravity               gravity          wua
# 8667                gravity               gravity          wug
# 22584           submersible           submersible          vwc
# 108                 gravity               gravity          vwc
# 39131                 other                 other          vwc
#
#       management_group                payment payment_type water_quality  \
# 9410        user-group                unknown      unknown         milky
# 18428       user-group              never pay    never pay          soft
# 12119       user-group         pay per bucket   per bucket          soft
# 10629       user-group         pay per bucket   per bucket          soft
# 2343        user-group                unknown      unknown          soft
# ...                ...                    ...          ...           ...
# 15137       user-group                unknown      unknown          soft
# 8667        user-group  pay when scheme fails   on failure          soft
# 22584       user-group              never pay    never pay          soft
# 108         user-group         pay per bucket   per bucket          soft
# 39131       user-group         pay per bucket   per bucket          soft
#
#       quality_group      quantity quantity_group                source  \
# 9410          milky        enough         enough          shallow well
# 18428          good        enough         enough          shallow well
# 12119          good  insufficient   insufficient           machine dbh
# 10629          good        enough         enough                spring
# 2343           good           dry            dry          shallow well
# ...             ...           ...            ...                   ...
# 15137          good  insufficient   insufficient  rainwater harvesting
# 8667           good        enough         enough                 river
# 22584          good        enough         enough                  lake
# 108            good           dry            dry                spring
# 39131          good           dry            dry                 river
#
#                 source_type source_class              waterpoint_type  \
# 9410           shallow well  groundwater                    hand pump
# 18428          shallow well  groundwater                    hand pump
# 12119              borehole  groundwater  communal standpipe multiple
# 10629                spring  groundwater           communal standpipe
# 2343           shallow well  groundwater                    hand pump
# ...                     ...          ...                          ...
# 15137  rainwater harvesting      surface           communal standpipe
# 8667             river/lake      surface           communal standpipe
# 22584            river/lake      surface  communal standpipe multiple
# 108                  spring  groundwater           communal standpipe
# 39131            river/lake      surface           communal standpipe
#
#       waterpoint_type_group    status_group
# 9410              hand pump  non functional
# 18428             hand pump      functional
# 12119    communal standpipe      functional
# 10629    communal standpipe      functional
# 2343              hand pump  non functional
# ...                     ...             ...
# 15137    communal standpipe      functional
# 8667     communal standpipe      functional
# 22584    communal standpipe  non functional
# 108      communal standpipe  non functional
# 39131    communal standpipe  non functional
#
# [59400 rows x 41 columns]

# %%
waterwells[waterwells['population'] == 0]['status_group'].value_counts()
# Out:
# functional                 11274
# non functional              8332
# functional needs repair     1775
# Name: status_group, dtype: int64

# %%
waterwells['funder'].value_counts()[(waterwells['funder'].value_counts() == 1)].index.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wl/0f_drsss6j3fltq3dgnjsj_m0000gn/T/ipykernel_36961/2884736597.py in <module>
# ----> 1 waterwells['funder'].value_counts()[(waterwells['funder'].value_counts() == 1)].index.tolist()
#
# NameError: name 'waterwells' is not defined

# %%
sum(waterwells['construction_year'].value_counts().index > 0)
# Out:
# 54
